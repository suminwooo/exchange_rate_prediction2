# %%
import pandas as pd

# %%
set01=pd.read_csv('data/set01')
set01=set01[['pred','actual']]
set02=pd.read_csv('data/set02')
set02=set02[['pred','actual']]
set03=pd.read_csv('data/set03')
set03=set03[['pred','actual']]
set04=pd.read_csv('data/set04')
set04=set04[['pred','actual']]
set05=pd.read_csv('data/set05')
set05=set05[['pred','actual']]
set06=pd.read_csv('data/set06')
set06=set06[['pred','actual']]
set07=pd.read_csv('data/set07')
set07=set07[['pred','actual']]
set08=pd.read_csv('data/set08')
set08=set08[['pred','actual']]
set09=pd.read_csv('data/set09')
set09=set09[['pred','actual']]
set10=pd.read_csv('data/set10')
set10=set10[['pred','actual']]
set11=pd.read_csv('data/set11')
set11=set11[['pred','actual']]
set12=pd.read_csv('data/set12')
set12=set12[['pred','actual']]

# %%
df_lastday= pd.DataFrame(data=[1117.2, 1117.8, 1137.8, 1158.2, 1190.0, 1156.8, 1182.0, 1215.2, 1201.3, 1168.4, 1179.3, 1157.8],
                        columns=['rate'], index=['2019-01-31', '2019-02-28', '2019-03-29', '2019-04-30', '2019-05-31', '2019-06-28',
                                                 '2019-07-31', '2019-08-30', '2019-09-30', '2019-10-31', '2019-11-29', '2019-12-31'])

# %%
set01.index=['set01 day1','set01 day2','set01 day3','set01 day4','set01 day5']
set02.index=['set02 day1','set02 day2','set02 day3','set02 day4','set02 day5']
set03.index=['set03 day1','set03 day2','set03 day3','set03 day4','set03 day5']
set04.index=['set04 day1','set04 day2','set04 day3','set04 day4','set04 day5']
set05.index=['set05 day1','set05 day2','set05 day3','set05 day4','set05 day5']
set06.index=['set06 day1','set06 day2','set06 day3','set06 day4','set06 day5']
set07.index=['set07 day1','set07 day2','set07 day3','set07 day4','set07 day5']
set08.index=['set08 day1','set08 day2','set08 day3','set08 day4','set08 day5']
set09.index=['set09 day1','set09 day2','set09 day3','set09 day4','set09 day5']
set10.index=['set10 day1','set10 day2','set10 day3','set10 day4','set10 day5']
set11.index=['set11 day1','set11 day2','set11 day3','set11 day4','set11 day5']
set12.index=['set12 day1','set12 day2','set12 day3','set12 day4','set12 day5']

# %% [markdown]
# #### set01

# %%
pred_updown=[]
actual_updown=[]

#pred

if set01.iloc[0,0]>df_lastday.iloc[0,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set01.iloc[1,0]>set01.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set01.iloc[2,0]>set01.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set01.iloc[3,0]>set01.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set01.iloc[4,0]>set01.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set01.iloc[0,1]>df_lastday.iloc[0,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set01.iloc[1,1]>set01.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set01.iloc[2,1]>set01.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set01.iloc[3,1]>set01.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set01.iloc[4,1]>set01.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set01['pred_updown']=pred_updown
set01['actual_updown']=actual_updown

# %% [markdown]
# #### set02

# %%
pred_updown=[]
actual_updown=[]

#pred

if set02.iloc[0,0]>df_lastday.iloc[1,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set02.iloc[1,0]>set02.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set02.iloc[2,0]>set02.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set02.iloc[3,0]>set02.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set02.iloc[4,0]>set02.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set02.iloc[0,1]>df_lastday.iloc[1,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set02.iloc[1,1]>set02.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set02.iloc[2,1]>set02.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set02.iloc[3,1]>set02.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set02.iloc[4,1]>set02.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set02['pred_updown']=pred_updown
set02['actual_updown']=actual_updown

# %% [markdown]
# #### set03

# %%
pred_updown=[]
actual_updown=[]

#pred

if set03.iloc[0,0]>df_lastday.iloc[2,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set03.iloc[1,0]>set03.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set03.iloc[2,0]>set03.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set03.iloc[3,0]>set03.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set03.iloc[4,0]>set03.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set03.iloc[0,1]>df_lastday.iloc[2,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set03.iloc[1,1]>set03.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set03.iloc[2,1]>set03.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set03.iloc[3,1]>set03.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set03.iloc[4,1]>set03.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set03['pred_updown']=pred_updown
set03['actual_updown']=actual_updown

# %% [markdown]
# #### set04

# %%
pred_updown=[]
actual_updown=[]

#pred

if set04.iloc[0,0]>df_lastday.iloc[3,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set04.iloc[1,0]>set04.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set04.iloc[2,0]>set04.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set04.iloc[3,0]>set04.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set04.iloc[4,0]>set04.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set04.iloc[0,1]>df_lastday.iloc[3,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set04.iloc[1,1]>set04.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set04.iloc[2,1]>set04.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set04.iloc[3,1]>set04.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set04.iloc[4,1]>set04.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set04['pred_updown']=pred_updown
set04['actual_updown']=actual_updown

# %% [markdown]
# #### set05

# %%
pred_updown=[]
actual_updown=[]

#pred

if set05.iloc[0,0]>df_lastday.iloc[4,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set05.iloc[1,0]>set05.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set05.iloc[2,0]>set05.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set05.iloc[3,0]>set05.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set05.iloc[4,0]>set05.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set05.iloc[0,1]>df_lastday.iloc[4,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set05.iloc[1,1]>set05.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set05.iloc[2,1]>set05.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set05.iloc[3,1]>set05.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set05.iloc[4,1]>set05.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set05['pred_updown']=pred_updown
set05['actual_updown']=actual_updown

# %% [markdown]
# #### set06

# %%
pred_updown=[]
actual_updown=[]

#pred

if set06.iloc[0,0]>df_lastday.iloc[5,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set06.iloc[1,0]>set06.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set06.iloc[2,0]>set06.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set06.iloc[3,0]>set06.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set06.iloc[4,0]>set06.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set06.iloc[0,1]>df_lastday.iloc[5,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set06.iloc[1,1]>set06.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set06.iloc[2,1]>set06.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set06.iloc[3,1]>set06.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set06.iloc[4,1]>set06.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set06['pred_updown']=pred_updown
set06['actual_updown']=actual_updown

# %% [markdown]
# #### set07

# %%
pred_updown=[]
actual_updown=[]

#pred

if set07.iloc[0,0]>df_lastday.iloc[6,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set07.iloc[1,0]>set07.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set07.iloc[2,0]>set07.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set07.iloc[3,0]>set07.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set07.iloc[4,0]>set07.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set07.iloc[0,1]>df_lastday.iloc[6,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set07.iloc[1,1]>set07.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set07.iloc[2,1]>set07.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set07.iloc[3,1]>set07.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set07.iloc[4,1]>set07.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set07['pred_updown']=pred_updown
set07['actual_updown']=actual_updown

# %% [markdown]
# #### set08

# %%
pred_updown=[]
actual_updown=[]

#pred

if set08.iloc[0,0]>df_lastday.iloc[7,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set08.iloc[1,0]>set08.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set08.iloc[2,0]>set08.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set08.iloc[3,0]>set08.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set08.iloc[4,0]>set08.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set08.iloc[0,1]>df_lastday.iloc[7,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set08.iloc[1,1]>set08.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set08.iloc[2,1]>set08.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set08.iloc[3,1]>set08.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set08.iloc[4,1]>set08.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set08['pred_updown']=pred_updown
set08['actual_updown']=actual_updown

# %% [markdown]
# #### set09

# %%
pred_updown=[]
actual_updown=[]

#pred

if set09.iloc[0,0]>df_lastday.iloc[8,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set09.iloc[1,0]>set09.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set09.iloc[2,0]>set09.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set09.iloc[3,0]>set09.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set09.iloc[4,0]>set09.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set09.iloc[0,1]>df_lastday.iloc[8,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set09.iloc[1,1]>set09.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set09.iloc[2,1]>set09.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set09.iloc[3,1]>set09.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set09.iloc[4,1]>set09.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set09['pred_updown']=pred_updown
set09['actual_updown']=actual_updown

# %% [markdown]
# #### set10

# %%
pred_updown=[]
actual_updown=[]

#pred

if set10.iloc[0,0]>df_lastday.iloc[9,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set10.iloc[1,0]>set10.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set10.iloc[2,0]>set10.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set10.iloc[3,0]>set10.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set10.iloc[4,0]>set10.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set10.iloc[0,1]>df_lastday.iloc[9,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set10.iloc[1,1]>set10.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set10.iloc[2,1]>set10.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set10.iloc[3,1]>set10.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set10.iloc[4,1]>set10.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set10['pred_updown']=pred_updown
set10['actual_updown']=actual_updown

# %% [markdown]
# #### set11

# %%
pred_updown=[]
actual_updown=[]

#pred

if set11.iloc[0,0]>df_lastday.iloc[10,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set11.iloc[1,0]>set11.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set11.iloc[2,0]>set11.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set11.iloc[3,0]>set11.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set11.iloc[4,0]>set11.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set11.iloc[0,1]>df_lastday.iloc[10,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set11.iloc[1,1]>set11.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set11.iloc[2,1]>set11.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set11.iloc[3,1]>set11.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set11.iloc[4,1]>set11.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set11['pred_updown']=pred_updown
set11['actual_updown']=actual_updown

# %% [markdown]
# #### set12

# %%
pred_updown=[]
actual_updown=[]

#pred

if set12.iloc[0,0]>df_lastday.iloc[11,0]:
    pred_updown.append('up')
else:
    pred_updown.append('down')
    
if set12.iloc[1,0]>set12.iloc[0,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set12.iloc[2,0]>set12.iloc[1,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')    
    
if set12.iloc[3,0]>set12.iloc[2,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')       
    
if set12.iloc[4,0]>set12.iloc[3,1]:
    pred_updown.append('up')
else:
    pred_updown.append('down')     
    
    
#actual

if set12.iloc[0,1]>df_lastday.iloc[11,0]:
    actual_updown.append('up')
else:
    actual_updown.append('down')
    
if set12.iloc[1,1]>set12.iloc[0,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set12.iloc[2,1]>set12.iloc[1,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    
    
if set12.iloc[3,1]>set12.iloc[2,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')       
    
if set12.iloc[4,1]>set12.iloc[3,1]:
    actual_updown.append('up')
else:
    actual_updown.append('down')    


set12['pred_updown']=pred_updown
set12['actual_updown']=actual_updown

# %%
set01
# Out:
#                pred  actual pred_updown actual_updown
# set01 day1  1128.37  1111.6          up          down
# set01 day2  1130.63  1116.8          up            up
# set01 day3  1131.84  1123.4          up            up
# set01 day4  1131.89  1124.5          up            up
# set01 day5  1131.10  1124.5          up          down

# %%
print('set 01 5일간예측:',(sum(set01['pred_updown'] == set01['actual_updown'])/5)*100)
print('set 02 5일간예측:',(sum(set02['pred_updown'] == set02['actual_updown'])/5)*100)
print('set 03 5일간예측:',(sum(set03['pred_updown'] == set03['actual_updown'])/5)*100)
print('set 04 5일간예측:',(sum(set04['pred_updown'] == set04['actual_updown'])/5)*100)
print('set 05 5일간예측:',(sum(set05['pred_updown'] == set05['actual_updown'])/5)*100)
print('set 06 5일간예측:',(sum(set06['pred_updown'] == set06['actual_updown'])/5)*100)
print('set 07 5일간예측:',(sum(set07['pred_updown'] == set07['actual_updown'])/5)*100)
print('set 08 5일간예측:',(sum(set08['pred_updown'] == set08['actual_updown'])/5)*100)
print('set 09 5일간예측:',(sum(set09['pred_updown'] == set09['actual_updown'])/5)*100)
print('set 10 5일간예측:',(sum(set10['pred_updown'] == set10['actual_updown'])/5)*100)
print('set 11 5일간예측:',(sum(set11['pred_updown'] == set11['actual_updown'])/5)*100)
print('set 12 5일간예측:',(sum(set12['pred_updown'] == set12['actual_updown'])/5)*100)
# Out:
# set 01 5일간예측: 60.0
# set 02 5일간예측: 0.0
# set 03 5일간예측: 100.0
# set 04 5일간예측: 0.0
# set 05 5일간예측: 20.0
# set 06 5일간예측: 40.0
# set 07 5일간예측: 20.0
# set 08 5일간예측: 40.0
# set 09 5일간예측: 20.0
# set 10 5일간예측: 60.0
# set 11 5일간예측: 100.0
# set 12 5일간예측: 40.0
