# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data01=pd.read_csv('data/final_01.csv')
data02=pd.read_csv('data/final_02.csv')
data03=pd.read_csv('data/final_03.csv')
data04=pd.read_csv('data/final_04.csv')
data05=pd.read_csv('data/final_05.csv')
data06=pd.read_csv('data/final_06.csv')
data07=pd.read_csv('data/final_07.csv')
data08=pd.read_csv('data/final_08.csv')
data09=pd.read_csv('data/final_09.csv')
data10=pd.read_csv('data/final_10.csv')
data11=pd.read_csv('data/final_11.csv')

# %%
data=pd.concat([data01,data02,data03,data04,data05,data06,data07,data08,
               data09,data10,data11])
data=data.reset_index()
data=data[['date','pred','actual']]
data=data.set_index('date')

# %%
plt.figure(figsize=(16,8))
plt.plot(data['pred'], label='pred')
plt.plot(data['actual'], label='actual')
plt.axvline(x='2019-02-01', color = 'g', linewidth=5, linestyle='--')

plt.axvline(x='2019-02-27', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-03-04', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-03-28', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-04-01', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-04-29', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-05-02', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-05-30', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-06-03', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-06-27', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-07-01', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-07-30', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-08-01', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-08-29', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-09-03', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-09-27', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-10-01', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-10-30', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-11-01', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2019-11-27', color = 'g', linewidth=3, linestyle='--')
plt.axvline(x='2019-12-02', color = 'g', linewidth=3, linestyle='--')

plt.axvline(x='2020-12-27', color = 'g', linewidth=5, linestyle='--')

plt.legend(loc='best')
plt.show()

# %%
final_01=pd.read_csv('data/final_01.csv')
final_02=pd.read_csv('data/final_02.csv')
final_03=pd.read_csv('data/final_03.csv')
final_04=pd.read_csv('data/final_04.csv')
final_05=pd.read_csv('data/final_05.csv')
final_06=pd.read_csv('data/final_06.csv')
final_07=pd.read_csv('data/final_07.csv')
final_08=pd.read_csv('data/final_08.csv')
final_09=pd.read_csv('data/final_09.csv')
final_10=pd.read_csv('data/final_10.csv')
final_11=pd.read_csv('data/final_11.csv')

# %%
oneday=[]
oneweek=[]
onemonth=[]

# %%
print('set01')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_01['pred_updown'] == final_01['actual_updown'])/len(final_01)*100,2), '%')
#5일만 예측
final_5_01=final_01[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_01['pred_updown'] == final_5_01['actual_updown'])/len(final_5_01)*100,2), '%')
#하루만예측
final_1_01=final_01[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_01['pred_updown'] == final_1_01['actual_updown'])/len(final_1_01)*100,2), '%')

print('set02')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_02['pred_updown'] == final_02['actual_updown'])/len(final_02)*100,2), '%')
#5일만 예측
final_5_02=final_02[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_02['pred_updown'] == final_5_02['actual_updown'])/len(final_5_02)*100,2), '%')
#하루만예측
final_1_02=final_02[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_02['pred_updown'] == final_1_02['actual_updown'])/len(final_1_02)*100,2), '%')

print('set03')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_03['pred_updown'] == final_03['actual_updown'])/len(final_03)*100,2), '%')
#5일만 예측
final_5_03=final_03[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_03['pred_updown'] == final_5_03['actual_updown'])/len(final_5_03)*100,2), '%')
#하루만예측
final_1_03=final_03[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_03['pred_updown'] == final_1_03['actual_updown'])/len(final_1_03)*100,2), '%')


print('set04')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_04['pred_updown'] == final_04['actual_updown'])/len(final_04)*100,2), '%')
#5일만 예측
final_5_04=final_04[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_04['pred_updown'] == final_5_04['actual_updown'])/len(final_5_04)*100,2), '%')
#하루만예측
final_1_04=final_04[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_04['pred_updown'] == final_1_04['actual_updown'])/len(final_1_04)*100,2), '%')


print('set05')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_05['pred_updown'] == final_05['actual_updown'])/len(final_05)*100,2), '%')
#5일만 예측
final_5_05=final_05[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_05['pred_updown'] == final_5_05['actual_updown'])/len(final_5_05)*100,2), '%')
#하루만예측
final_1_05=final_05[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_05['pred_updown'] == final_1_05['actual_updown'])/len(final_1_05)*100,2), '%')


print('set06')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_06['pred_updown'] == final_06['actual_updown'])/len(final_06)*100,2), '%')
#5일만 예측
final_5_06=final_06[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_06['pred_updown'] == final_5_06['actual_updown'])/len(final_5_06)*100,2), '%')
#하루만예측
final_1_06=final_06[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_06['pred_updown'] == final_1_06['actual_updown'])/len(final_1_06)*100,2), '%')


print('set07')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_07['pred_updown'] == final_07['actual_updown'])/len(final_07)*100,2), '%')
#5일만 예측
final_5_07=final_07[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_07['pred_updown'] == final_5_07['actual_updown'])/len(final_5_07)*100,2), '%')
#하루만예측
final_1_07=final_07[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_07['pred_updown'] == final_1_07['actual_updown'])/len(final_1_07)*100,2), '%')


print('set08')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_08['pred_updown'] == final_08['actual_updown'])/len(final_08)*100,2), '%')
#5일만 예측
final_5_08=final_08[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_08['pred_updown'] == final_5_08['actual_updown'])/len(final_5_08)*100,2), '%')
#하루만예측
final_1_08=final_08[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_08['pred_updown'] == final_1_08['actual_updown'])/len(final_1_08)*100,2), '%')


print('set09')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_09['pred_updown'] == final_09['actual_updown'])/len(final_09)*100,2), '%')
#5일만 예측
final_5_09=final_09[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_09['pred_updown'] == final_5_09['actual_updown'])/len(final_5_09)*100,2), '%')
#하루만예측
final_1_09=final_09[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_09['pred_updown'] == final_1_09['actual_updown'])/len(final_1_09)*100,2), '%')


print('set10')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_10['pred_updown'] == final_10['actual_updown'])/len(final_10)*100,2), '%')
#5일만 예측
final_5_10=final_10[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_10['pred_updown'] == final_5_10['actual_updown'])/len(final_5_10)*100,2), '%')
#하루만예측
final_1_10=final_10[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_10['pred_updown'] == final_1_10['actual_updown'])/len(final_1_10)*100,2), '%')


print('set11')
# 한달간 예측
print('한달간 상승,하락 정확도 : ',round(sum(final_11['pred_updown'] == final_11['actual_updown'])/len(final_11)*100,2), '%')
#5일만 예측
final_5_11=final_11[:5]
print('5일간 상승,하락 정확도 : ',round(sum(final_5_11['pred_updown'] == final_5_11['actual_updown'])/len(final_5_11)*100,2), '%')
#하루만예측
final_1_11=final_11[:1]
print('다음날 상승,하락 정확도 : ',round(sum(final_1_11['pred_updown'] == final_1_11['actual_updown'])/len(final_1_11)*100,2), '%')
# Out:
# set01
# 한달간 상승,하락 정확도 :  40.0 %
# 5일간 상승,하락 정확도 :  60.0 %
# 다음날 상승,하락 정확도 :  0.0 %
# set02
# 한달간 상승,하락 정확도 :  78.95 %
# 5일간 상승,하락 정확도 :  100.0 %
# 다음날 상승,하락 정확도 :  100.0 %
# set03
# 한달간 상승,하락 정확도 :  30.0 %
# 5일간 상승,하락 정확도 :  40.0 %
# 다음날 상승,하락 정확도 :  100.0 %
# set04
# 한달간 상승,하락 정확도 :  15.79 %
# 5일간 상승,하락 정확도 :  0.0 %
# 다음날 상승,하락 정확도 :  0.0 %
# set05
# 한달간 상승,하락 정확도 :  77.78 %
# 5일간 상승,하락 정확도 :  80.0 %
# 다음날 상승,하락 정확도 :  100.0 %
# set06
# 한달간 상승,하락 정확도 :  38.1 %
# 5일간 상승,하락 정확도 :  20.0 %
# 다음날 상승,하락 정확도 :  100.0 %
# set07
# 한달간 상승,하락 정확도 :  35.0 %
# 5일간 상승,하락 정확도 :  0.0 %
# 다음날 상승,하락 정확도 :  0.0 %
# set08
# 한달간 상승,하락 정확도 :  47.06 %
# 5일간 상승,하락 정확도 :  0.0 %
# 다음날 상승,하락 정확도 :  0.0 %
# set09
# 한달간 상승,하락 정확도 :  35.0 %
# 5일간 상승,하락 정확도 :  20.0 %
# 다음날 상승,하락 정확도 :  0.0 %
# set10
# 한달간 상승,하락 정확도 :  52.63 %
# 5일간 상승,하락 정확도 :  20.0 %
# 다음날 상승,하락 정확도 :  0.0 %
# set11
# 한달간 상승,하락 정확도 :  63.16 %
# 5일간 상승,하락 정확도 :  40.0 %
# 다음날 상승,하락 정확도 :  0.0 %
